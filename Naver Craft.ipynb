# %%
pip install -U craft-text-detector
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting craft-text-detector
#   Using cached craft_text_detector-0.4.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: opencv-python<4.5.4.62,>=3.4.8.29 in c:\users\kimym\appdata\roaming\python\python39\site-packages (from craft-text-detector) (4.5.4.60)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from craft-text-detector) (1.7.3)
# Requirement already satisfied: torch>=1.6.0 in c:\users\kimym\appdata\roaming\python\python39\site-packages (from craft-text-detector) (1.13.0)
# Collecting gdown>=3.10.1
#   Using cached gdown-4.5.3-py3-none-any.whl
# Collecting torchvision>=0.7.0
#   Using cached torchvision-0.14.0-cp39-cp39-win_amd64.whl (1.1 MB)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->craft-text-detector) (1.16.0)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->craft-text-detector) (4.64.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->craft-text-detector) (3.6.0)
# Requirement already satisfied: requests[socks] in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->craft-text-detector) (2.28.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from gdown>=3.10.1->craft-text-detector) (4.11.1)
# Requirement already satisfied: numpy>=1.19.3 in c:\programdata\anaconda3\lib\site-packages (from opencv-python<4.5.4.62,>=3.4.8.29->craft-text-detector) (1.21.5)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch>=1.6.0->craft-text-detector) (4.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision>=0.7.0->craft-text-detector) (9.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->craft-text-detector) (2.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (2022.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->craft-text-detector) (1.7.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->gdown>=3.10.1->craft-text-detector) (0.4.5)
# Installing collected packages: torchvision, gdown, craft-text-detector
# Successfully installed craft-text-detector-0.4.3 gdown-4.5.3 torchvision-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
#   WARNING: The script gdown.exe is installed in 'C:\Users\KimYM\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)

# %%
# import Craft class
from craft_text_detector import Craft

# set image path and export folder directory
path = './Downloads/123/Colab Notebooks/pills_test/' # can be filepath, PIL image or numpy array
filename = '1025.jpg'
output_dir = 'outputs/'

# create a craft instance
craft = Craft(output_dir=output_dir, crop_type="poly", cuda=False)

# apply craft text detection and export detected regions to output directory
prediction_result = craft.detect_text(path+filename)

# unload models from ram/gpu
craft.unload_craftnet_model()
craft.unload_refinenet_model()
# Out:
# C:\Users\KimYM\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and may be removed in the future. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# C:\Users\KimYM\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\KimYM\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
# import craft functions
from craft_text_detector import (
    read_image,
    load_craftnet_model,
    load_refinenet_model,
    get_prediction,
    export_detected_regions,
    export_extra_results,
    empty_cuda_cache
)

# set image path and export folder directory
path = './Downloads/123/Colab Notebooks/pills_test/' # can be filepath, PIL image or numpy array
filename = '1024.jpg'
image = path + filename
output_dir = 'outputs/'

# read image
image = read_image(image)

# load models
refine_net = load_refinenet_model(cuda=False)
craft_net = load_craftnet_model(cuda=False)

# perform prediction
prediction_result = get_prediction(
    image=image,
    craft_net=craft_net,
    refine_net=refine_net,
    text_threshold=0.7,
    link_threshold=0.4,
    low_text=0.4,
    cuda=False,
    long_size=1280
)

# export detected text regions
exported_file_paths = export_detected_regions(
    image=image,
    regions=prediction_result["boxes"],
    output_dir=output_dir,
    rectify=True
)

# export heatmap, detection points, box visualization
export_extra_results(
    image=image,
    regions=prediction_result["boxes"],
    heatmaps=prediction_result["heatmaps"],
    output_dir=output_dir
)

# unload models from gpu
empty_cuda_cache()

# %%
import torch

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9754171181780405714
#  xla_global_id: -1]

# %%
pip install -U torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in c:\users\kimym\appdata\roaming\python\python39\site-packages (1.13.0)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu117/torch-1.13.0%2Bcu117-cp39-cp39-win_amd64.whl (2258.1 MB)
#      ---------------------------------------- 2.3/2.3 GB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in c:\users\kimym\appdata\roaming\python\python39\site-packages (0.14.0)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu117/torchvision-0.14.0%2Bcu117-cp39-cp39-win_amd64.whl (4.8 MB)
#      ---------------------------------------- 4.8/4.8 MB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: torchaudio in c:\users\kimym\appdata\roaming\python\python39\site-packages (0.13.0+cu117)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch) (4.3.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\programdata\anaconda3\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->torchvision) (1.26.11)
# Installing collected packages: torch, torchvision
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0
#     Uninstalling torch-1.13.0:
#       Successfully uninstalled torch-1.13.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
#   WARNING: The scripts convert-caffe2-to-onnx.exe, convert-onnx-to-caffe2.exe and torchrun.exe are installed in 'C:\Users\KimYM\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\KimYM\\AppData\\Roaming\\Python\\Python39\\site-packages\\~orch\\lib\\asmjit.dll'
# Check the permissions.
#
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\kimym\appdata\roaming\python\python39\site-packages)

# %%
conda install pytorch torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - pytorch
#     - pytorch-cuda=11.7
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.10.11 |       haa95532_0         125 KB
#     certifi-2022.9.24          |   py39haa95532_0         154 KB
#     conda-22.9.0               |   py39haa95532_0         888 KB
#     cuda-11.7.1                |                0           1 KB  nvidia
#     cuda-cccl-11.7.91          |                0         1.2 MB  nvidia
#     cuda-command-line-tools-11.7.1|                0           1 KB  nvidia
#     cuda-compiler-11.7.1       |                0           1 KB  nvidia
#     cuda-cudart-11.7.99        |                0         1.4 MB  nvidia
#     cuda-cudart-dev-11.7.99    |                0         711 KB  nvidia
#     cuda-cuobjdump-11.7.91     |                0         2.5 MB  nvidia
#     cuda-cupti-11.7.101        |                0        10.2 MB  nvidia
#     cuda-cuxxfilt-11.7.91      |                0         165 KB  nvidia
#     cuda-demo-suite-11.8.86    |                0         4.7 MB  nvidia
#     cuda-documentation-11.8.86 |                0          91 KB  nvidia
#     cuda-libraries-11.7.1      |                0           1 KB  nvidia
#     cuda-libraries-dev-11.7.1  |                0           1 KB  nvidia
#     cuda-memcheck-11.8.86      |                0         183 KB  nvidia
#     cuda-nsight-compute-11.8.0 |                0           1 KB  nvidia
#     cuda-nvcc-11.7.99          |                0        44.0 MB  nvidia
#     cuda-nvdisasm-11.8.86      |                0        48.9 MB  nvidia
#     cuda-nvml-dev-11.7.91      |                0          85 KB  nvidia
#     cuda-nvprof-11.8.87        |                0         1.5 MB  nvidia
#     cuda-nvprune-11.7.91       |                0         152 KB  nvidia
#     cuda-nvrtc-11.7.99         |                0        71.9 MB  nvidia
#     cuda-nvrtc-dev-11.7.99     |                0        14.3 MB  nvidia
#     cuda-nvtx-11.7.91          |                0          43 KB  nvidia
#     cuda-nvvp-11.8.87          |                0       113.6 MB  nvidia
#     cuda-runtime-11.7.1        |                0           1 KB  nvidia
#     cuda-sanitizer-api-11.8.86 |                0        12.7 MB  nvidia
#     cuda-toolkit-11.7.1        |                0           1 KB  nvidia
#     cuda-tools-11.7.1          |                0           1 KB  nvidia
#     cuda-visual-tools-11.7.1   |                0           1 KB  nvidia
#     libcublas-11.11.3.6        |                0          33 KB  nvidia
#     libcublas-dev-11.11.3.6    |                0       375.9 MB  nvidia
#     libcufft-10.9.0.58         |                0           6 KB  nvidia
#     libcufft-dev-10.9.0.58     |                0       144.6 MB  nvidia
#     libcurand-10.3.0.86        |                0           3 KB  nvidia
#     libcurand-dev-10.3.0.86    |                0        51.2 MB  nvidia
#     libcusolver-11.4.1.48      |                0          29 KB  nvidia
#     libcusolver-dev-11.4.1.48  |                0        94.1 MB  nvidia
#     libcusparse-11.7.5.86      |                0          13 KB  nvidia
#     libcusparse-dev-11.7.5.86  |                0       175.7 MB  nvidia
#     libnpp-11.8.0.86           |                0         294 KB  nvidia
#     libnpp-dev-11.8.0.86       |                0       143.2 MB  nvidia
#     libnvjpeg-11.9.0.86        |                0           4 KB  nvidia
#     libnvjpeg-dev-11.9.0.86    |                0         1.9 MB  nvidia
#     libuv-1.40.0               |       he774522_0         255 KB
#     nsight-compute-2022.3.0.22 |                0       455.0 MB  nvidia
#     pytorch-1.13.0             |py3.9_cuda11.7_cudnn8_0        1.10 GB  pytorch
#     pytorch-cuda-11.7          |       h67b0de4_0           7 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     torchaudio-0.13.0          |       py39_cu117         4.6 MB  pytorch
#     torchvision-0.14.0         |       py39_cu117         7.5 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        2.84 GB
#
# The following NEW packages will be INSTALLED:
#
#   cuda               nvidia/win-64::cuda-11.7.1-0
#   cuda-cccl          nvidia/win-64::cuda-cccl-11.7.91-0
#   cuda-command-line~ nvidia/win-64::cuda-command-line-tools-11.7.1-0
#   cuda-compiler      nvidia/win-64::cuda-compiler-11.7.1-0
#   cuda-cudart        nvidia/win-64::cuda-cudart-11.7.99-0
#   cuda-cudart-dev    nvidia/win-64::cuda-cudart-dev-11.7.99-0
#   cuda-cuobjdump     nvidia/win-64::cuda-cuobjdump-11.7.91-0
#   cuda-cupti         nvidia/win-64::cuda-cupti-11.7.101-0
#   cuda-cuxxfilt      nvidia/win-64::cuda-cuxxfilt-11.7.91-0
#   cuda-demo-suite    nvidia/win-64::cuda-demo-suite-11.8.86-0
#   cuda-documentation nvidia/win-64::cuda-documentation-11.8.86-0
#   cuda-libraries     nvidia/win-64::cuda-libraries-11.7.1-0
#   cuda-libraries-dev nvidia/win-64::cuda-libraries-dev-11.7.1-0
#   cuda-memcheck      nvidia/win-64::cuda-memcheck-11.8.86-0
#   cuda-nsight-compu~ nvidia/win-64::cuda-nsight-compute-11.8.0-0
#   cuda-nvcc          nvidia/win-64::cuda-nvcc-11.7.99-0
#   cuda-nvdisasm      nvidia/win-64::cuda-nvdisasm-11.8.86-0
#   cuda-nvml-dev      nvidia/win-64::cuda-nvml-dev-11.7.91-0
#   cuda-nvprof        nvidia/win-64::cuda-nvprof-11.8.87-0
#   cuda-nvprune       nvidia/win-64::cuda-nvprune-11.7.91-0
#   cuda-nvrtc         nvidia/win-64::cuda-nvrtc-11.7.99-0
#   cuda-nvrtc-dev     nvidia/win-64::cuda-nvrtc-dev-11.7.99-0
#   cuda-nvtx          nvidia/win-64::cuda-nvtx-11.7.91-0
#   cuda-nvvp          nvidia/win-64::cuda-nvvp-11.8.87-0
#   cuda-runtime       nvidia/win-64::cuda-runtime-11.7.1-0
#   cuda-sanitizer-api nvidia/win-64::cuda-sanitizer-api-11.8.86-0
#   cuda-toolkit       nvidia/win-64::cuda-toolkit-11.7.1-0
#   cuda-tools         nvidia/win-64::cuda-tools-11.7.1-0
#   cuda-visual-tools  nvidia/win-64::cuda-visual-tools-11.7.1-0
#   libcublas          nvidia/win-64::libcublas-11.11.3.6-0
#   libcublas-dev      nvidia/win-64::libcublas-dev-11.11.3.6-0
#   libcufft           nvidia/win-64::libcufft-10.9.0.58-0
#   libcufft-dev       nvidia/win-64::libcufft-dev-10.9.0.58-0
#   libcurand          nvidia/win-64::libcurand-10.3.0.86-0
#   libcurand-dev      nvidia/win-64::libcurand-dev-10.3.0.86-0
#   libcusolver        nvidia/win-64::libcusolver-11.4.1.48-0
#   libcusolver-dev    nvidia/win-64::libcusolver-dev-11.4.1.48-0
#   libcusparse        nvidia/win-64::libcusparse-11.7.5.86-0
#   libcusparse-dev    nvidia/win-64::libcusparse-dev-11.7.5.86-0
#   libnpp             nvidia/win-64::libnpp-11.8.0.86-0
#   libnpp-dev         nvidia/win-64::libnpp-dev-11.8.0.86-0
#   libnvjpeg          nvidia/win-64::libnvjpeg-11.9.0.86-0
#   libnvjpeg-dev      nvidia/win-64::libnvjpeg-dev-11.9.0.86-0
#   libuv              pkgs/main/win-64::libuv-1.40.0-he774522_0
#   nsight-compute     nvidia/win-64::nsight-compute-2022.3.0.22-0
#   pytorch            pytorch/win-64::pytorch-1.13.0-py3.9_cuda11.7_cudnn8_0
#   pytorch-cuda       pytorch/noarch::pytorch-cuda-11.7-h67b0de4_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   torchaudio         pytorch/win-64::torchaudio-0.13.0-py39_cu117
#   torchvision        pytorch/win-64::torchvision-0.14.0-py39_cu117
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.07.19-haa95532_0 --> 2022.10.11-haa95532_0
#   certifi                          2022.6.15-py39haa95532_0 --> 2022.9.24-py39haa95532_0
#   conda                               4.14.0-py39haa95532_0 --> 22.9.0-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# cuda-command-line-to | 1 KB      |            |   0%
# cuda-command-line-to | 1 KB      | ########## | 100%
# cuda-command-line-to | 1 KB      | ########## | 100%
#
# libcusolver-11.4.1.4 | 29 KB     |            |   0%
# libcusolver-11.4.1.4 | 29 KB     | ########## | 100%
# libcusolver-11.4.1.4 | 29 KB     | ########## | 100%
#
# cuda-libraries-11.7. | 1 KB      |            |   0%
# cuda-libraries-11.7. | 1 KB      | ########## | 100%
# cuda-libraries-11.7. | 1 KB      | ########## | 100%
#
# cuda-cuxxfilt-11.7.9 | 165 KB    |            |   0%
# cuda-cuxxfilt-11.7.9 | 165 KB    | ########## | 100%
# cuda-cuxxfilt-11.7.9 | 165 KB    | ########## | 100%
#
# cuda-nvml-dev-11.7.9 | 85 KB     |            |   0%
# cuda-nvml-dev-11.7.9 | 85 KB     | ########## | 100%
# cuda-nvml-dev-11.7.9 | 85 KB     | ########## | 100%
#
# libcusparse-dev-11.7 | 175.7 MB  |            |   0%
# libcusparse-dev-11.7 | 175.7 MB  | ########## | 100%
# libcusparse-dev-11.7 | 175.7 MB  | ########## | 100%
#
# libcublas-dev-11.11. | 375.9 MB  |            |   0%
# libcublas-dev-11.11. | 375.9 MB  | ########## | 100%
# libcublas-dev-11.11. | 375.9 MB  | ########## | 100%
#
# cuda-cccl-11.7.91    | 1.2 MB    |            |   0%
# cuda-cccl-11.7.91    | 1.2 MB    | ########## | 100%
# cuda-cccl-11.7.91    | 1.2 MB    | ########## | 100%
#
# cuda-toolkit-11.7.1  | 1 KB      |            |   0%
# cuda-toolkit-11.7.1  | 1 KB      | ########## | 100%
# cuda-toolkit-11.7.1  | 1 KB      | ########## | 100%
#
# certifi-2022.9.24    | 154 KB    |            |   0%
# certifi-2022.9.24    | 154 KB    | ########## | 100%
# certifi-2022.9.24    | 154 KB    | ########## | 100%
#
# cuda-sanitizer-api-1 | 12.7 MB   |            |   0%
# cuda-sanitizer-api-1 | 12.7 MB   | ########## | 100%
# cuda-sanitizer-api-1 | 12.7 MB   | ########## | 100%
#
# pytorch-mutex-1.0    | 3 KB      |            |   0%
# pytorch-mutex-1.0    | 3 KB      | ########## | 100%
#
# conda-22.9.0         | 888 KB    |            |   0%
# conda-22.9.0         | 888 KB    | ########## | 100%
# conda-22.9.0         | 888 KB    | ########## | 100%
#
# pytorch-1.13.0       | 1.10 GB   |            |   0%
# pytorch-1.13.0       | 1.10 GB   |            |   0%
# pytorch-1.13.0       | 1.10 GB   |            |   0%
# pytorch-1.13.0       | 1.10 GB   |            |   1%
# pytorch-1.13.0       | 1.10 GB   |            |   1%
# pytorch-1.13.0       | 1.10 GB   | 1          |   1%
# pytorch-1.13.0       | 1.10 GB   | 1          |   1%
# pytorch-1.13.0       | 1.10 GB   | 1          |   2%
# pytorch-1.13.0       | 1.10 GB   | 1          |   2%
# pytorch-1.13.0       | 1.10 GB   | 2          |   2%
# pytorch-1.13.0       | 1.10 GB   | 2          |   2%
# pytorch-1.13.0       | 1.10 GB   | 2          |   3%
# pytorch-1.13.0       | 1.10 GB   | 2          |   3%
# pytorch-1.13.0       | 1.10 GB   | 3          |   3%
# pytorch-1.13.0       | 1.10 GB   | 3          |   4%
# pytorch-1.13.0       | 1.10 GB   | 3          |   4%
# pytorch-1.13.0       | 1.10 GB   | 4          |   4%
# pytorch-1.13.0       | 1.10 GB   | 4          |   5%
# pytorch-1.13.0       | 1.10 GB   | 4          |   5%
# pytorch-1.13.0       | 1.10 GB   | 5          |   5%
# pytorch-1.13.0       | 1.10 GB   | 5          |   5%
# pytorch-1.13.0       | 1.10 GB   | 5          |   6%
# pytorch-1.13.0       | 1.10 GB   | 6          |   6%
# pytorch-1.13.0       | 1.10 GB   | 6          |   6%
# pytorch-1.13.0       | 1.10 GB   | 6          |   7%
# pytorch-1.13.0       | 1.10 GB   | 6          |   7%
# pytorch-1.13.0       | 1.10 GB   | 7          |   7%
# pytorch-1.13.0       | 1.10 GB   | 7          |   8%
# pytorch-1.13.0       | 1.10 GB   | 7          |   8%
# pytorch-1.13.0       | 1.10 GB   | 8          |   8%
# pytorch-1.13.0       | 1.10 GB   | 8          |   9%
# pytorch-1.13.0       | 1.10 GB   | 8          |   9%
# pytorch-1.13.0       | 1.10 GB   | 9          |   9%
# pytorch-1.13.0       | 1.10 GB   | 9          |  10%
# pytorch-1.13.0       | 1.10 GB   | 9          |  10%
# pytorch-1.13.0       | 1.10 GB   | #          |  10%
# pytorch-1.13.0       | 1.10 GB   | #          |  11%
# pytorch-1.13.0       | 1.10 GB   | #          |  11%
# pytorch-1.13.0       | 1.10 GB   | #1         |  11%
# pytorch-1.13.0       | 1.10 GB   | #1         |  12%
# pytorch-1.13.0       | 1.10 GB   | #1         |  12%
# pytorch-1.13.0       | 1.10 GB   | #2         |  12%
# pytorch-1.13.0       | 1.10 GB   | #2         |  12%
# pytorch-1.13.0       | 1.10 GB   | #2         |  13%
# pytorch-1.13.0       | 1.10 GB   | #2         |  13%
# pytorch-1.13.0       | 1.10 GB   | #3         |  13%
# pytorch-1.13.0       | 1.10 GB   | #3         |  14%
# pytorch-1.13.0       | 1.10 GB   | #3         |  14%
# pytorch-1.13.0       | 1.10 GB   | #4         |  14%
# pytorch-1.13.0       | 1.10 GB   | #4         |  14%
# pytorch-1.13.0       | 1.10 GB   | #4         |  15%
# pytorch-1.13.0       | 1.10 GB   | #4         |  15%
# pytorch-1.13.0       | 1.10 GB   | #5         |  15%
# pytorch-1.13.0       | 1.10 GB   | #5         |  15%
# pytorch-1.13.0       | 1.10 GB   | #5         |  16%
# pytorch-1.13.0       | 1.10 GB   | #5         |  16%
# pytorch-1.13.0       | 1.10 GB   | #6         |  16%
# pytorch-1.13.0       | 1.10 GB   | #6         |  16%
# pytorch-1.13.0       | 1.10 GB   | #6         |  17%
# pytorch-1.13.0       | 1.10 GB   | #7         |  17%
# pytorch-1.13.0       | 1.10 GB   | #7         |  17%
# pytorch-1.13.0       | 1.10 GB   | #7         |  18%
# pytorch-1.13.0       | 1.10 GB   | #7         |  18%
# pytorch-1.13.0       | 1.10 GB   | #8         |  18%
# pytorch-1.13.0       | 1.10 GB   | #8         |  18%
# pytorch-1.13.0       | 1.10 GB   | #8         |  19%
# pytorch-1.13.0       | 1.10 GB   | #8         |  19%
# pytorch-1.13.0       | 1.10 GB   | #9         |  19%
# pytorch-1.13.0       | 1.10 GB   | #9         |  19%
# pytorch-1.13.0       | 1.10 GB   | #9         |  20%
# pytorch-1.13.0       | 1.10 GB   | #9         |  20%
# pytorch-1.13.0       | 1.10 GB   | ##         |  20%
# pytorch-1.13.0       | 1.10 GB   | ##         |  20%
# pytorch-1.13.0       | 1.10 GB   | ##         |  21%
# pytorch-1.13.0       | 1.10 GB   | ##1        |  21%
# pytorch-1.13.0       | 1.10 GB   | ##1        |  21%
# pytorch-1.13.0       | 1.10 GB   | ##1        |  22%
# pytorch-1.13.0       | 1.10 GB   | ##2        |  22%
# pytorch-1.13.0       | 1.10 GB   | ##2        |  22%
# pytorch-1.13.0       | 1.10 GB   | ##2        |  23%
# pytorch-1.13.0       | 1.10 GB   | ##2        |  23%
# pytorch-1.13.0       | 1.10 GB   | ##3        |  23%
# pytorch-1.13.0       | 1.10 GB   | ##3        |  24%
# pytorch-1.13.0       | 1.10 GB   | ##3        |  24%
# pytorch-1.13.0       | 1.10 GB   | ##4        |  24%
# pytorch-1.13.0       | 1.10 GB   | ##4        |  25%
# pytorch-1.13.0       | 1.10 GB   | ##4        |  25%
# pytorch-1.13.0       | 1.10 GB   | ##5        |  25%
# pytorch-1.13.0       | 1.10 GB   | ##5        |  26%
# pytorch-1.13.0       | 1.10 GB   | ##5        |  26%
# pytorch-1.13.0       | 1.10 GB   | ##6        |  26%
# pytorch-1.13.0       | 1.10 GB   | ##6        |  27%
# pytorch-1.13.0       | 1.10 GB   | ##6        |  27%
# pytorch-1.13.0       | 1.10 GB   | ##7        |  27%
# pytorch-1.13.0       | 1.10 GB   | ##7        |  28%
# pytorch-1.13.0       | 1.10 GB   | ##7        |  28%
# pytorch-1.13.0       | 1.10 GB   | ##8        |  28%
# pytorch-1.13.0       | 1.10 GB   | ##8        |  29%
# pytorch-1.13.0       | 1.10 GB   | ##8        |  29%
# pytorch-1.13.0       | 1.10 GB   | ##9        |  29%
# pytorch-1.13.0       | 1.10 GB   | ##9        |  29%
# pytorch-1.13.0       | 1.10 GB   | ##9        |  30%
# pytorch-1.13.0       | 1.10 GB   | ###        |  30%
# pytorch-1.13.0       | 1.10 GB   | ###        |  30%
# pytorch-1.13.0       | 1.10 GB   | ###        |  31%
# pytorch-1.13.0       | 1.10 GB   | ###1       |  31%
# pytorch-1.13.0       | 1.10 GB   | ###1       |  31%
# pytorch-1.13.0       | 1.10 GB   | ###1       |  32%
# pytorch-1.13.0       | 1.10 GB   | ###2       |  32%
# pytorch-1.13.0       | 1.10 GB   | ###2       |  32%
# pytorch-1.13.0       | 1.10 GB   | ###2       |  33%
# pytorch-1.13.0       | 1.10 GB   | ###3       |  33%
# pytorch-1.13.0       | 1.10 GB   | ###3       |  33%
# pytorch-1.13.0       | 1.10 GB   | ###3       |  34%
# pytorch-1.13.0       | 1.10 GB   | ###4       |  34%
# pytorch-1.13.0       | 1.10 GB   | ###4       |  34%
# pytorch-1.13.0       | 1.10 GB   | ###4       |  35%
# pytorch-1.13.0       | 1.10 GB   | ###5       |  35%
# pytorch-1.13.0       | 1.10 GB   | ###5       |  35%
# pytorch-1.13.0       | 1.10 GB   | ###5       |  36%
# pytorch-1.13.0       | 1.10 GB   | ###6       |  36%
# pytorch-1.13.0       | 1.10 GB   | ###6       |  36%
# pytorch-1.13.0       | 1.10 GB   | ###6       |  37%
# pytorch-1.13.0       | 1.10 GB   | ###7       |  37%
# pytorch-1.13.0       | 1.10 GB   | ###7       |  37%
# pytorch-1.13.0       | 1.10 GB   | ###7       |  38%
# pytorch-1.13.0       | 1.10 GB   | ###8       |  38%
# pytorch-1.13.0       | 1.10 GB   | ###8       |  39%
# pytorch-1.13.0       | 1.10 GB   | ###8       |  39%
# pytorch-1.13.0       | 1.10 GB   | ###9       |  39%
# pytorch-1.13.0       | 1.10 GB   | ###9       |  39%
# pytorch-1.13.0       | 1.10 GB   | ###9       |  40%
# pytorch-1.13.0       | 1.10 GB   | ####       |  40%
# pytorch-1.13.0       | 1.10 GB   | ####       |  41%
# pytorch-1.13.0       | 1.10 GB   | ####       |  41%
# pytorch-1.13.0       | 1.10 GB   | ####1      |  41%
# pytorch-1.13.0       | 1.10 GB   | ####1      |  42%
# pytorch-1.13.0       | 1.10 GB   | ####1      |  42%
# pytorch-1.13.0       | 1.10 GB   | ####2      |  42%
# pytorch-1.13.0       | 1.10 GB   | ####2      |  43%
# pytorch-1.13.0       | 1.10 GB   | ####2      |  43%
# pytorch-1.13.0       | 1.10 GB   | ####3      |  43%
# pytorch-1.13.0       | 1.10 GB   | ####3      |  44%
# pytorch-1.13.0       | 1.10 GB   | ####3      |  44%
# pytorch-1.13.0       | 1.10 GB   | ####4      |  44%
# pytorch-1.13.0       | 1.10 GB   | ####4      |  45%
# pytorch-1.13.0       | 1.10 GB   | ####4      |  45%
# pytorch-1.13.0       | 1.10 GB   | ####5      |  45%
# pytorch-1.13.0       | 1.10 GB   | ####5      |  45%
# pytorch-1.13.0       | 1.10 GB   | ####5      |  46%
# pytorch-1.13.0       | 1.10 GB   | ####5      |  46%
# pytorch-1.13.0       | 1.10 GB   | ####6      |  46%
# pytorch-1.13.0       | 1.10 GB   | ####6      |  46%
# pytorch-1.13.0       | 1.10 GB   | ####6      |  47%
# pytorch-1.13.0       | 1.10 GB   | ####6      |  47%
# pytorch-1.13.0       | 1.10 GB   | ####7      |  47%
# pytorch-1.13.0       | 1.10 GB   | ####7      |  47%
# pytorch-1.13.0       | 1.10 GB   | ####7      |  48%
# pytorch-1.13.0       | 1.10 GB   | ####8      |  48%
# pytorch-1.13.0       | 1.10 GB   | ####8      |  48%
# pytorch-1.13.0       | 1.10 GB   | ####8      |  49%
# pytorch-1.13.0       | 1.10 GB   | ####8      |  49%
# pytorch-1.13.0       | 1.10 GB   | ####9      |  49%
# pytorch-1.13.0       | 1.10 GB   | ####9      |  50%
# pytorch-1.13.0       | 1.10 GB   | ####9      |  50%
# pytorch-1.13.0       | 1.10 GB   | #####      |  50%
# pytorch-1.13.0       | 1.10 GB   | #####      |  51%
# pytorch-1.13.0       | 1.10 GB   | #####      |  51%
# pytorch-1.13.0       | 1.10 GB   | #####1     |  51%
# pytorch-1.13.0       | 1.10 GB   | #####1     |  52%
# pytorch-1.13.0       | 1.10 GB   | #####1     |  52%
# pytorch-1.13.0       | 1.10 GB   | #####2     |  52%
# pytorch-1.13.0       | 1.10 GB   | #####2     |  53%
# pytorch-1.13.0       | 1.10 GB   | #####2     |  53%
# pytorch-1.13.0       | 1.10 GB   | #####3     |  53%
# pytorch-1.13.0       | 1.10 GB   | #####3     |  54%
# pytorch-1.13.0       | 1.10 GB   | #####4     |  54%
# pytorch-1.13.0       | 1.10 GB   | #####4     |  54%
# pytorch-1.13.0       | 1.10 GB   | #####4     |  55%
# pytorch-1.13.0       | 1.10 GB   | #####4     |  55%
# pytorch-1.13.0       | 1.10 GB   | #####5     |  55%
# pytorch-1.13.0       | 1.10 GB   | #####5     |  56%
# pytorch-1.13.0       | 1.10 GB   | #####5     |  56%
# pytorch-1.13.0       | 1.10 GB   | #####6     |  56%
# pytorch-1.13.0       | 1.10 GB   | #####6     |  57%
# pytorch-1.13.0       | 1.10 GB   | #####6     |  57%
# pytorch-1.13.0       | 1.10 GB   | #####7     |  57%
# pytorch-1.13.0       | 1.10 GB   | #####7     |  57%
# pytorch-1.13.0       | 1.10 GB   | #####7     |  58%
# pytorch-1.13.0       | 1.10 GB   | #####8     |  58%
# pytorch-1.13.0       | 1.10 GB   | #####8     |  58%
# pytorch-1.13.0       | 1.10 GB   | #####8     |  59%
# pytorch-1.13.0       | 1.10 GB   | #####9     |  59%
# pytorch-1.13.0       | 1.10 GB   | #####9     |  59%
# pytorch-1.13.0       | 1.10 GB   | #####9     |  60%
# pytorch-1.13.0       | 1.10 GB   | #####9     |  60%
# pytorch-1.13.0       | 1.10 GB   | ######     |  60%
# pytorch-1.13.0       | 1.10 GB   | ######     |  61%
# pytorch-1.13.0       | 1.10 GB   | ######     |  61%
# pytorch-1.13.0       | 1.10 GB   | ######1    |  61%
# pytorch-1.13.0       | 1.10 GB   | ######1    |  61%
# pytorch-1.13.0       | 1.10 GB   | ######1    |  62%
# pytorch-1.13.0       | 1.10 GB   | ######1    |  62%
# pytorch-1.13.0       | 1.10 GB   | ######2    |  62%
# pytorch-1.13.0       | 1.10 GB   | ######2    |  63%
# pytorch-1.13.0       | 1.10 GB   | ######2    |  63%
# pytorch-1.13.0       | 1.10 GB   | ######3    |  63%
# pytorch-1.13.0       | 1.10 GB   | ######3    |  63%
# pytorch-1.13.0       | 1.10 GB   | ######3    |  64%
# pytorch-1.13.0       | 1.10 GB   | ######4    |  64%
# pytorch-1.13.0       | 1.10 GB   | ######4    |  64%
# pytorch-1.13.0       | 1.10 GB   | ######4    |  65%
# pytorch-1.13.0       | 1.10 GB   | ######4    |  65%
# pytorch-1.13.0       | 1.10 GB   | ######5    |  65%
# pytorch-1.13.0       | 1.10 GB   | ######5    |  66%
# pytorch-1.13.0       | 1.10 GB   | ######5    |  66%
# pytorch-1.13.0       | 1.10 GB   | ######6    |  66%
# pytorch-1.13.0       | 1.10 GB   | ######6    |  66%
# pytorch-1.13.0       | 1.10 GB   | ######6    |  67%
# pytorch-1.13.0       | 1.10 GB   | ######6    |  67%
# pytorch-1.13.0       | 1.10 GB   | ######7    |  67%
# pytorch-1.13.0       | 1.10 GB   | ######7    |  68%
# pytorch-1.13.0       | 1.10 GB   | ######7    |  68%
# pytorch-1.13.0       | 1.10 GB   | ######8    |  68%
# pytorch-1.13.0       | 1.10 GB   | ######8    |  68%
# pytorch-1.13.0       | 1.10 GB   | ######8    |  69%
# pytorch-1.13.0       | 1.10 GB   | ######8    |  69%
# pytorch-1.13.0       | 1.10 GB   | ######9    |  69%
# pytorch-1.13.0       | 1.10 GB   | ######9    |  69%
# pytorch-1.13.0       | 1.10 GB   | ######9    |  70%
# pytorch-1.13.0       | 1.10 GB   | ######9    |  70%
# pytorch-1.13.0       | 1.10 GB   | #######    |  70%
# pytorch-1.13.0       | 1.10 GB   | #######    |  70%
# pytorch-1.13.0       | 1.10 GB   | #######    |  71%
# pytorch-1.13.0       | 1.10 GB   | #######    |  71%
# pytorch-1.13.0       | 1.10 GB   | #######1   |  71%
# pytorch-1.13.0       | 1.10 GB   | #######1   |  72%
# pytorch-1.13.0       | 1.10 GB   | #######1   |  72%
# pytorch-1.13.0       | 1.10 GB   | #######2   |  72%
# pytorch-1.13.0       | 1.10 GB   | #######2   |  73%
# pytorch-1.13.0       | 1.10 GB   | #######2   |  73%
# pytorch-1.13.0       | 1.10 GB   | #######3   |  73%
# pytorch-1.13.0       | 1.10 GB   | #######3   |  74%
# pytorch-1.13.0       | 1.10 GB   | #######3   |  74%
# pytorch-1.13.0       | 1.10 GB   | #######4   |  74%
# pytorch-1.13.0       | 1.10 GB   | #######4   |  75%
# pytorch-1.13.0       | 1.10 GB   | #######4   |  75%
# pytorch-1.13.0       | 1.10 GB   | #######5   |  75%
# pytorch-1.13.0       | 1.10 GB   | #######5   |  76%
# pytorch-1.13.0       | 1.10 GB   | #######5   |  76%
# pytorch-1.13.0       | 1.10 GB   | #######6   |  76%
# pytorch-1.13.0       | 1.10 GB   | #######6   |  77%
# pytorch-1.13.0       | 1.10 GB   | #######6   |  77%
# pytorch-1.13.0       | 1.10 GB   | #######7   |  77%
# pytorch-1.13.0       | 1.10 GB   | #######7   |  78%
# pytorch-1.13.0       | 1.10 GB   | #######7   |  78%
# pytorch-1.13.0       | 1.10 GB   | #######8   |  78%
# pytorch-1.13.0       | 1.10 GB   | #######8   |  79%
# pytorch-1.13.0       | 1.10 GB   | #######8   |  79%
# pytorch-1.13.0       | 1.10 GB   | #######9   |  79%
# pytorch-1.13.0       | 1.10 GB   | #######9   |  80%
# pytorch-1.13.0       | 1.10 GB   | ########   |  80%
# pytorch-1.13.0       | 1.10 GB   | ########   |  80%
# pytorch-1.13.0       | 1.10 GB   | ########   |  81%
# pytorch-1.13.0       | 1.10 GB   | ########   |  81%
# pytorch-1.13.0       | 1.10 GB   | ########1  |  81%
# pytorch-1.13.0       | 1.10 GB   | ########1  |  82%
# pytorch-1.13.0       | 1.10 GB   | ########2  |  82%
# pytorch-1.13.0       | 1.10 GB   | ########2  |  82%
# pytorch-1.13.0       | 1.10 GB   | ########2  |  83%
# pytorch-1.13.0       | 1.10 GB   | ########3  |  83%
# pytorch-1.13.0       | 1.10 GB   | ########3  |  83%
# pytorch-1.13.0       | 1.10 GB   | ########3  |  84%
# pytorch-1.13.0       | 1.10 GB   | ########4  |  84%
# pytorch-1.13.0       | 1.10 GB   | ########4  |  84%
# pytorch-1.13.0       | 1.10 GB   | ########4  |  85%
# pytorch-1.13.0       | 1.10 GB   | ########4  |  85%
# pytorch-1.13.0       | 1.10 GB   | ########5  |  85%
# pytorch-1.13.0       | 1.10 GB   | ########5  |  85%
# pytorch-1.13.0       | 1.10 GB   | ########5  |  86%
# pytorch-1.13.0       | 1.10 GB   | ########5  |  86%
# pytorch-1.13.0       | 1.10 GB   | ########6  |  86%
# pytorch-1.13.0       | 1.10 GB   | ########6  |  86%
# pytorch-1.13.0       | 1.10 GB   | ########6  |  87%
# pytorch-1.13.0       | 1.10 GB   | ########6  |  87%
# pytorch-1.13.0       | 1.10 GB   | ########7  |  87%
# pytorch-1.13.0       | 1.10 GB   | ########7  |  88%
# pytorch-1.13.0       | 1.10 GB   | ########7  |  88%
# pytorch-1.13.0       | 1.10 GB   | ########8  |  88%
# pytorch-1.13.0       | 1.10 GB   | ########8  |  88%
# pytorch-1.13.0       | 1.10 GB   | ########8  |  89%
# pytorch-1.13.0       | 1.10 GB   | ########8  |  89%
# pytorch-1.13.0       | 1.10 GB   | ########9  |  89%
# pytorch-1.13.0       | 1.10 GB   | ########9  |  89%
# pytorch-1.13.0       | 1.10 GB   | ########9  |  90%
# pytorch-1.13.0       | 1.10 GB   | ########9  |  90%
# pytorch-1.13.0       | 1.10 GB   | #########  |  90%
# pytorch-1.13.0       | 1.10 GB   | #########  |  91%
# pytorch-1.13.0       | 1.10 GB   | #########  |  91%
# pytorch-1.13.0       | 1.10 GB   | #########1 |  91%
# pytorch-1.13.0       | 1.10 GB   | #########1 |  91%
# pytorch-1.13.0       | 1.10 GB   | #########1 |  92%
# pytorch-1.13.0       | 1.10 GB   | #########1 |  92%
# pytorch-1.13.0       | 1.10 GB   | #########2 |  92%
# pytorch-1.13.0       | 1.10 GB   | #########2 |  92%
# pytorch-1.13.0       | 1.10 GB   | #########2 |  93%
# pytorch-1.13.0       | 1.10 GB   | #########2 |  93%
# pytorch-1.13.0       | 1.10 GB   | #########3 |  93%
# pytorch-1.13.0       | 1.10 GB   | #########3 |  93%
# pytorch-1.13.0       | 1.10 GB   | #########3 |  94%
# pytorch-1.13.0       | 1.10 GB   | #########3 |  94%
# pytorch-1.13.0       | 1.10 GB   | #########4 |  94%
# pytorch-1.13.0       | 1.10 GB   | #########4 |  94%
# pytorch-1.13.0       | 1.10 GB   | #########4 |  95%
# pytorch-1.13.0       | 1.10 GB   | #########5 |  95%
# pytorch-1.13.0       | 1.10 GB   | #########5 |  95%
# pytorch-1.13.0       | 1.10 GB   | #########5 |  96%
# pytorch-1.13.0       | 1.10 GB   | #########5 |  96%
# pytorch-1.13.0       | 1.10 GB   | #########6 |  96%
# pytorch-1.13.0       | 1.10 GB   | #########6 |  96%
# pytorch-1.13.0       | 1.10 GB   | #########6 |  97%
# pytorch-1.13.0       | 1.10 GB   | #########6 |  97%
# pytorch-1.13.0       | 1.10 GB   | #########7 |  97%
# pytorch-1.13.0       | 1.10 GB   | #########7 |  97%
# pytorch-1.13.0       | 1.10 GB   | #########7 |  98%
# pytorch-1.13.0       | 1.10 GB   | #########7 |  98%
# pytorch-1.13.0       | 1.10 GB   | #########8 |  98%
# pytorch-1.13.0       | 1.10 GB   | #########8 |  98%
# pytorch-1.13.0       | 1.10 GB   | #########8 |  99%
# pytorch-1.13.0       | 1.10 GB   | #########9 |  99%
# pytorch-1.13.0       | 1.10 GB   | #########9 |  99%
# pytorch-1.13.0       | 1.10 GB   | #########9 | 100%
# pytorch-1.13.0       | 1.10 GB   | #########9 | 100%
# pytorch-1.13.0       | 1.10 GB   | ########## | 100%
#
# cuda-runtime-11.7.1  | 1 KB      |            |   0%
# cuda-runtime-11.7.1  | 1 KB      | ########## | 100%
# cuda-runtime-11.7.1  | 1 KB      | ########## | 100%
#
# libcublas-11.11.3.6  | 33 KB     |            |   0%
# libcublas-11.11.3.6  | 33 KB     | ########## | 100%
# libcublas-11.11.3.6  | 33 KB     | ########## | 100%
#
# libcurand-10.3.0.86  | 3 KB      |            |   0%
# libcurand-10.3.0.86  | 3 KB      | ########## | 100%
# libcurand-10.3.0.86  | 3 KB      | ########## | 100%
#
# cuda-nvrtc-11.7.99   | 71.9 MB   |            |   0%
# cuda-nvrtc-11.7.99   | 71.9 MB   | ########## | 100%
# cuda-nvrtc-11.7.99   | 71.9 MB   | ########## | 100%
#
# cuda-compiler-11.7.1 | 1 KB      |            |   0%
# cuda-compiler-11.7.1 | 1 KB      | ########## | 100%
# cuda-compiler-11.7.1 | 1 KB      | ########## | 100%
#
# torchaudio-0.13.0    | 4.6 MB    |            |   0%
# torchaudio-0.13.0    | 4.6 MB    | ##2        |  22%
# torchaudio-0.13.0    | 4.6 MB    | ########5  |  85%
# torchaudio-0.13.0    | 4.6 MB    | ########## | 100%
#
# libnvjpeg-11.9.0.86  | 4 KB      |            |   0%
# libnvjpeg-11.9.0.86  | 4 KB      | ########## | 100%
# libnvjpeg-11.9.0.86  | 4 KB      | ########## | 100%
#
# cuda-cudart-11.7.99  | 1.4 MB    |            |   0%
# cuda-cudart-11.7.99  | 1.4 MB    | ########## | 100%
# cuda-cudart-11.7.99  | 1.4 MB    | ########## | 100%
#
# cuda-tools-11.7.1    | 1 KB      |            |   0%
# cuda-tools-11.7.1    | 1 KB      | ########## | 100%
# cuda-tools-11.7.1    | 1 KB      | ########## | 100%
#
# cuda-cudart-dev-11.7 | 711 KB    |            |   0%
# cuda-cudart-dev-11.7 | 711 KB    | ########## | 100%
# cuda-cudart-dev-11.7 | 711 KB    | ########## | 100%
#
# cuda-nsight-compute- | 1 KB      |            |   0%
# cuda-nsight-compute- | 1 KB      | ########## | 100%
# cuda-nsight-compute- | 1 KB      | ########## | 100%
#
# cuda-memcheck-11.8.8 | 183 KB    |            |   0%
# cuda-memcheck-11.8.8 | 183 KB    | ########## | 100%
# cuda-memcheck-11.8.8 | 183 KB    | ########## | 100%
#
# libcufft-dev-10.9.0. | 144.6 MB  |            |   0%
# libcufft-dev-10.9.0. | 144.6 MB  | ########## | 100%
# libcufft-dev-10.9.0. | 144.6 MB  | ########## | 100%
#
# cuda-nvrtc-dev-11.7. | 14.3 MB   |            |   0%
# cuda-nvrtc-dev-11.7. | 14.3 MB   | ########## | 100%
# cuda-nvrtc-dev-11.7. | 14.3 MB   | ########## | 100%
#
# cuda-visual-tools-11 | 1 KB      |            |   0%
# cuda-visual-tools-11 | 1 KB      | ########## | 100%
# cuda-visual-tools-11 | 1 KB      | ########## | 100%
#
# libnpp-dev-11.8.0.86 | 143.2 MB  |            |   0%
# libnpp-dev-11.8.0.86 | 143.2 MB  | ########## | 100%
# libnpp-dev-11.8.0.86 | 143.2 MB  | ########## | 100%
#
# libcurand-dev-10.3.0 | 51.2 MB   |            |   0%
# libcurand-dev-10.3.0 | 51.2 MB   | ########## | 100%
# libcurand-dev-10.3.0 | 51.2 MB   | ########## | 100%
#
# cuda-11.7.1          | 1 KB      |            |   0%
# cuda-11.7.1          | 1 KB      | ########## | 100%
# cuda-11.7.1          | 1 KB      | ########## | 100%
#
# cuda-cuobjdump-11.7. | 2.5 MB    |            |   0%
# cuda-cuobjdump-11.7. | 2.5 MB    | ########## | 100%
# cuda-cuobjdump-11.7. | 2.5 MB    | ########## | 100%
#
# cuda-documentation-1 | 91 KB     |            |   0%
# cuda-documentation-1 | 91 KB     | ########## | 100%
# cuda-documentation-1 | 91 KB     | ########## | 100%
#
# libuv-1.40.0         | 255 KB    |            |   0%
# libuv-1.40.0         | 255 KB    | ########## | 100%
#
# cuda-cupti-11.7.101  | 10.2 MB   |            |   0%
# cuda-cupti-11.7.101  | 10.2 MB   | ########## | 100%
# cuda-cupti-11.7.101  | 10.2 MB   | ########## | 100%
#
# cuda-nvprune-11.7.91 | 152 KB    |            |   0%
# cuda-nvprune-11.7.91 | 152 KB    | ########## | 100%
# cuda-nvprune-11.7.91 | 152 KB    | ########## | 100%
#
# cuda-nvcc-11.7.99    | 44.0 MB   |            |   0%
# cuda-nvcc-11.7.99    | 44.0 MB   | ########## | 100%
# cuda-nvcc-11.7.99    | 44.0 MB   | ########## | 100%
#
# cuda-nvvp-11.8.87    | 113.6 MB  |            |   0%
# cuda-nvvp-11.8.87    | 113.6 MB  | ########## | 100%
# cuda-nvvp-11.8.87    | 113.6 MB  | ########## | 100%
#
# cuda-nvtx-11.7.91    | 43 KB     |            |   0%
# cuda-nvtx-11.7.91    | 43 KB     | ########## | 100%
# cuda-nvtx-11.7.91    | 43 KB     | ########## | 100%
#
# libnpp-11.8.0.86     | 294 KB    |            |   0%
# libnpp-11.8.0.86     | 294 KB    | ########## | 100%
# libnpp-11.8.0.86     | 294 KB    | ########## | 100%
#
# libcufft-10.9.0.58   | 6 KB      |            |   0%
# libcufft-10.9.0.58   | 6 KB      | ########## | 100%
# libcufft-10.9.0.58   | 6 KB      | ########## | 100%
#
# ca-certificates-2022 | 125 KB    |            |   0%
# ca-certificates-2022 | 125 KB    | ########## | 100%
#
# libcusparse-11.7.5.8 | 13 KB     |            |   0%
# libcusparse-11.7.5.8 | 13 KB     | ########## | 100%
# libcusparse-11.7.5.8 | 13 KB     | ########## | 100%
#
# libcusolver-dev-11.4 | 94.1 MB   |            |   0%
# libcusolver-dev-11.4 | 94.1 MB   | ########## | 100%
# libcusolver-dev-11.4 | 94.1 MB   | ########## | 100%
#
# torchvision-0.14.0   | 7.5 MB    |            |   0%
# torchvision-0.14.0   | 7.5 MB    | #5         |  16%
# torchvision-0.14.0   | 7.5 MB    | #####1     |  51%
# torchvision-0.14.0   | 7.5 MB    | #########4 |  95%
# torchvision-0.14.0   | 7.5 MB    | ########## | 100%
#
# cuda-nvprof-11.8.87  | 1.5 MB    |            |   0%
# cuda-nvprof-11.8.87  | 1.5 MB    | ########## | 100%
# cuda-nvprof-11.8.87  | 1.5 MB    | ########## | 100%
#
# cuda-nvdisasm-11.8.8 | 48.9 MB   |            |   0%
# cuda-nvdisasm-11.8.8 | 48.9 MB   | ########## | 100%
# cuda-nvdisasm-11.8.8 | 48.9 MB   | ########## | 100%
#
# cuda-demo-suite-11.8 | 4.7 MB    |            |   0%
# cuda-demo-suite-11.8 | 4.7 MB    | ########## | 100%
# cuda-demo-suite-11.8 | 4.7 MB    | ########## | 100%
#
# libnvjpeg-dev-11.9.0 | 1.9 MB    |            |   0%
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ########## | 100%
# libnvjpeg-dev-11.9.0 | 1.9 MB    | ########## | 100%
#
# cuda-libraries-dev-1 | 1 KB      |            |   0%
# cuda-libraries-dev-1 | 1 KB      | ########## | 100%
# cuda-libraries-dev-1 | 1 KB      | ########## | 100%
#
# nsight-compute-2022. | 455.0 MB  |            |   0%
# nsight-compute-2022. | 455.0 MB  | ########## | 100%
# nsight-compute-2022. | 455.0 MB  | ########## | 100%
#
# pytorch-cuda-11.7    | 7 KB      |            |   0%
# pytorch-cuda-11.7    | 7 KB      | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\Anaconda3

# %%
torch.cuda_version

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
torch.__version__
# Out:
# '1.13.0+cpu'

# %%
dir(craft)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'craft_net',
#  'crop_type',
#  'cuda',
#  'detect_text',
#  'export_extra',
#  'link_threshold',
#  'load_craftnet_model',
#  'load_refinenet_model',
#  'long_size',
#  'low_text',
#  'output_dir',
#  'rectify',
#  'refine_net',
#  'refiner',
#  'text_threshold',
#  'unload_craftnet_model',
#  'unload_refinenet_model']

# %%
craft.load_craftnet_model(path+filename)
# Out:
# C:\Users\KimYM\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:252: UserWarning: Accessing the model URLs via the internal dictionary of the module is deprecated since 0.13 and may be removed in the future. Please access them via the appropriate Weights Enum instead.
#   warnings.warn(
# C:\Users\KimYM\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\KimYM\AppData\Roaming\Python\Python39\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 craft.load_craftnet_model(path+filename)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\craft_text_detector\__init__.py:87, in Craft.load_craftnet_model(self, weight_path)
#      83 def load_craftnet_model(self, weight_path: Optional[str] = None):
#      84     """
#      85     Loads craftnet model
#      86     """
# ---> 87     self.craft_net = load_craftnet_model(self.cuda, weight_path=weight_path)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\craft_text_detector\craft_utils.py:75, in load_craftnet_model(cuda, weight_path)
#      72     torch_utils.cudnn_benchmark = False
#      73 else:
#      74     craft_net.load_state_dict(
# ---> 75         copyStateDict(torch_utils.load(weight_path, map_location="cpu"))
#      76     )
#      77 craft_net.eval()
#      78 return craft_net
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\serialization.py:795, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     793     except RuntimeError as e:
#     794         raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 795 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\torch\serialization.py:1002, in _legacy_load(f, map_location, pickle_module, **pickle_load_args)
#     996 if not hasattr(f, 'readinto') and (3, 8, 0) <= sys.version_info < (3, 8, 2):
#     997     raise RuntimeError(
#     998         "torch.load does not work with file-like objects that do not implement readinto on Python 3.8.0 and 3.8.1. "
#     999         f"Received object of type \"{type(f)}\". Please update to Python 3.8.2 or newer to restore this "
#    1000         "functionality.")
# -> 1002 magic_number = pickle_module.load(f, **pickle_load_args)
#    1003 if magic_number != MAGIC_NUMBER:
#    1004     raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, '\xff'.

# %%
path+filename
# Out:
# './Downloads/123/Colab Notebooks/pills_test/1024.jpg'

# %%
craft.detect_text(path+filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 craft.detect_text(path+filename)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\craft_text_detector\__init__.py:131, in Craft.detect_text(self, image, image_path)
#     128     image = image_path
#     130 # perform prediction
# --> 131 prediction_result = get_prediction(
#     132     image=image,
#     133     craft_net=self.craft_net,
#     134     refine_net=self.refine_net,
#     135     text_threshold=self.text_threshold,
#     136     link_threshold=self.link_threshold,
#     137     low_text=self.low_text,
#     138     cuda=self.cuda,
#     139     long_size=self.long_size,
#     140 )
#     142 # arange regions
#     143 if self.crop_type == "box":
#
# File ~\AppData\Roaming\Python\Python39\site-packages\craft_text_detector\predict.py:68, in get_prediction(image, craft_net, refine_net, text_threshold, link_threshold, low_text, cuda, long_size, poly)
#      66 # forward pass
#      67 with torch_utils.no_grad():
# ---> 68     y, feature = craft_net(x)
#      69 craftnet_time = time.time() - t0
#      70 t0 = time.time()
#
# TypeError: 'NoneType' object is not callable
